# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
# %pylab inline
# %config InlineBackend.figure_formats = ['retina']
from imutils import paths
import time   # time1 = time.time(); print('Time taken: {:.1f} sec'.format(time.time() - time1))
import cv2
import pickle
import warnings
warnings.filterwarnings("ignore")
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import keras
import keras.utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam

from tensorflow.keras import utils as np_utils

from keras.utils import to_categorical
from keras.preprocessing import image
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Convolution1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense

# %%
from google.colab import drive
drive.mount._DEBUG = True
drive.mount('/content/MyDrive', force_remount=True)
# Out:
# unset HISTFILE; export PS1="root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: "
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# /content# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: umount -f /content/MyDrive || umount /content/MyDrive; pkill -9 -x drive
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: pkill -9 -f /opt/google/drive/directoryprefetcher_binary
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: ( while `sleep 0.5`; do if [[ -d "/content/MyDrive" && "$(ls -A /content/MyDrive)" != "" ]]; then echo "google.colab.drive MOUNTED"; break; fi; done ) &
# [1] 45929
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: ( /opt/google/drive/drive --features=fuse_max_background:1000,max_read_qps:1000,max_write_qps:1000,max_operation_batch_size:15,max_parallel_push_task_instances:10,opendir_timeout_ms:120000,virtual_folders_omit_spaces:true,read_only_mode:false --inet_family=IPV4_ONLY --metadata_server_auth_uri=172.28.0.1:8009/computeMetadata/v1 --preferences=trusted_root_certs_file_path:/opt/google/drive/roots.pem,mount_point_path:/content/MyDrive 2>&1 | grep --line-buffered -E "Drive File Stream encountered a problem and has stopped|The domain policy has disabled Drive File Stream"; echo "drive EXITED"; ) &
# [2] 45931
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: google.colab.drive MOUNTED
# fuser -kw "/root/.config/Google/DriveFS/Logs/timeouts.txt" ; rm -rf "/root/.config/Google/DriveFS/Logs/timeouts.txt"
# /root/.config/Google/DriveFS/Logs/timeouts.txt:  1508
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: nohup bash -c 'tail -n +0 -F "/root/.config/Google/DriveFS/Logs/drive_fs.txt" | python3 /opt/google/drive/drive-filter.py > "/root/.config/Google/DriveFS/Logs/timeouts.txt" ' < /dev/null > /dev/null 2>&1 &
# [3] 46014
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: nohup bash -c '/opt/google/drive/directoryprefetcher_binary -mountpoint=/content/MyDrive' >> /root/.config/Google/DriveFS/Logs/dpb.txt 2>&1 &
# [4] 46017
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: disown -a
# root@a321331d36b7-1cf208f4f970445d96bcda4d75acee6f: exit
# Mounted at /content/MyDrive

# %%
# Enter the directory
# !cd /content/MyDrive/MyDrive/ECG/

# %%
import numpy as np

# Generate dummy data for demonstration purposes
X_train = np.random.rand(100, 10)  # Example: 100 samples, 10 features
X_test = np.random.rand(50, 10)    # Example: 50 samples, 10 features
y_train = np.random.randint(0, 2, 100)  # Example: binary labels for 100 samples
y_test = np.random.randint(0, 2, 50)    # Example: binary labels for 50 samples

# Now you can proceed to create the dataset dictionary and save it to a pickle file

# %%
import pickle

# Assuming you have your data stored in X_train, X_test, y_train, y_test variables

# Create the dataset dictionary
dataset_dict = {
    'X_train': X_train,
    'X_test': X_test,
    'y_train': y_train,
    'y_test': y_test
}

# Specify the file path for saving the dictionary
pickle_file_path = '/content/MyDrive/MyDrive/ECG/dataset_dict.pickle'

# Save the dataset dictionary to a pickle file
with open(pickle_file_path, 'wb') as file:
    pickle.dump(dataset_dict, file)

# Now dataset_dict_moise.pickle contains your dataset dictionary

# %%
dataset_dict.keys()
# Out:
# dict_keys(['X_train', 'X_test', 'y_train', 'y_test'])

# %%
x_train1=dataset_dict['X_train']
x_test1=dataset_dict['X_test']

y_train1=dataset_dict['y_train']
y_test1=dataset_dict['y_test']

y_test = to_categorical(y_test1)[:,1:5] # Since labeling is [1,2,3,4] instead \
# of [0,1,2,3]
y_train = to_categorical(y_train1)[:,1:5] #one-hot encoding

# %%
y_train.shape
# Out:
# (100, 1)

# %%
comb_x=np.concatenate([x_train1, x_test1],axis=0)
comb_y=np.concatenate([y_train, y_test],axis=0)

# %%
from sklearn.model_selection import train_test_split

# Assuming comb_x and comb_y are your combined features and labels respectively
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(comb_x, comb_y, random_state=100, test_size=0.2, stratify=comb_y)

# No need to access specific channels if data is already two-dimensional
# If you have multi-channel data, ensure that it's properly shaped before accessing channels

# Example of expanding dimensions for compatibility with Convolutional Neural Network (CNN) models
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)

# %%
x_train, x_test, y_train, y_test = train_test_split(comb_x, comb_y, random_state=100, test_size=0.2, stratify=comb_y)

x_train=x_train[:,:,1]
x_test=x_test[:,:,1]


x_train=np.expand_dims(x_train,2)
x_test=np.expand_dims(x_test,2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-b32f2afb0a41> in <cell line: 3>()
#       1 x_train, x_test, y_train, y_test = train_test_split(comb_x, comb_y, random_state=100, test_size=0.2, stratify=comb_y)
#       2
# ----> 3 x_train=x_train[:,:,1]
#       4 x_test=x_test[:,:,1]
#       5
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)

# %%
x_train = x_train[:, :, 0]
x_test = x_test[:, :, 0]

# %%
# x_test.reshape(742,1980,1)
print(x_test.shape)

y_test.shape
# Out:
# (30, 10)
# (30, 1)

# %%
num_classes=4

# %%
model_m = Sequential()
input_shape=(x_train.shape[1], 1)
model_m.add(Conv1D(128, kernel_size=3,padding = 'same',activation='relu', input_shape=input_shape))
model_m.add(BatchNormalization())
model_m.add(MaxPooling1D(pool_size=(2)))

## CONV2
model_m.add(Conv1D(64,kernel_size=3,padding = 'same', activation='relu'))
model_m.add(BatchNormalization())
model_m.add(MaxPooling1D(pool_size=(2)))
## End CONV2

model_m.add(Flatten())
model_m.add(Dense(64, activation='tanh'))
model_m.add(Dropout(0.1))
# model_m.add(Dense(32, activation='tanh'))
# model_m.add(Dropout(0.2))
model_m.add(Dense(16, activation='relu'))
model_m.add(Dropout(0.2))
model_m.add(Dense(num_classes, activation='softmax'))
model_m.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 10, 128)           512
#
#  batch_normalization_10 (Ba  (None, 10, 128)           512
#  tchNormalization)
#
#  max_pooling1d_10 (MaxPooli  (None, 5, 128)            0
#  ng1D)
#
#  conv1d_11 (Conv1D)          (None, 5, 64)             24640
#
#  batch_normalization_11 (Ba  (None, 5, 64)             256
#  tchNormalization)
#
#  max_pooling1d_11 (MaxPooli  (None, 2, 64)             0
#  ng1D)
#
#  flatten_5 (Flatten)         (None, 128)               0
#
#  dense_63 (Dense)            (None, 64)                8256
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_64 (Dense)            (None, 16)                1040
#
#  dropout_11 (Dropout)        (None, 16)                0
#
#  dense_65 (Dense)            (None, 4)                 68
#
# =================================================================
# Total params: 35284 (137.83 KB)
# Trainable params: 34900 (136.33 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %%
# Check the shape of X_train and X_test
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (100, 10)
# X_test shape: (50, 10)

# %%
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (120, 1)
# y_test shape: (30, 1)

# %%
model_m = Sequential([
    Dense(64, activation='relu', input_shape=(10,)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')  # Adjust output size for binary classification
])

# %%
model_m = Sequential([
    Dense(64, activation='relu', input_shape=(10,)),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')  # Adjust output size for 4 classes
])

# %%
from tensorflow.keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=4)  # Assuming 4 classes

# %%
model_m.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

# Hyper-parameters
BATCH_SIZE = 50
EPOCHS = 50

# Enable validation to use ModelCheckpoint and EarlyStopping callbacks.
shape=x_train.shape
history = model_m.fit(x_train,
                      y_train_one_hot,
                      batch_size=BATCH_SIZE,
                      epochs=EPOCHS,
                      validation_split=0.1,
                      verbose=1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 126ms/step - loss: 1.3267 - accuracy: 0.3519 - val_loss: 1.2368 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2356 - accuracy: 0.5370 - val_loss: 1.1734 - val_accuracy: 0.4167
# Epoch 3/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1584 - accuracy: 0.5463 - val_loss: 1.1189 - val_accuracy: 0.4167
# Epoch 4/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0959 - accuracy: 0.5463 - val_loss: 1.0716 - val_accuracy: 0.4167
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0407 - accuracy: 0.5463 - val_loss: 1.0334 - val_accuracy: 0.4167
# Epoch 6/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9933 - accuracy: 0.5463 - val_loss: 1.0001 - val_accuracy: 0.4167
# Epoch 7/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9519 - accuracy: 0.5463 - val_loss: 0.9685 - val_accuracy: 0.4167
# Epoch 8/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9141 - accuracy: 0.5463 - val_loss: 0.9336 - val_accuracy: 0.4167
# Epoch 9/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8801 - accuracy: 0.5463 - val_loss: 0.9010 - val_accuracy: 0.4167
# Epoch 10/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.8490 - accuracy: 0.5463 - val_loss: 0.8695 - val_accuracy: 0.4167
# Epoch 11/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8210 - accuracy: 0.5463 - val_loss: 0.8439 - val_accuracy: 0.4167
# Epoch 12/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7969 - accuracy: 0.5463 - val_loss: 0.8283 - val_accuracy: 0.4167
# Epoch 13/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7766 - accuracy: 0.5463 - val_loss: 0.8083 - val_accuracy: 0.4167
# Epoch 14/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7579 - accuracy: 0.5463 - val_loss: 0.7841 - val_accuracy: 0.4167
# Epoch 15/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7395 - accuracy: 0.5463 - val_loss: 0.7620 - val_accuracy: 0.4167
# Epoch 16/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7245 - accuracy: 0.5463 - val_loss: 0.7397 - val_accuracy: 0.4167
# Epoch 17/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7145 - accuracy: 0.5648 - val_loss: 0.7231 - val_accuracy: 0.5000
# Epoch 18/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7047 - accuracy: 0.5556 - val_loss: 0.7135 - val_accuracy: 0.5000
# Epoch 19/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6974 - accuracy: 0.5833 - val_loss: 0.7000 - val_accuracy: 0.6667
# Epoch 20/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6933 - accuracy: 0.6111 - val_loss: 0.6914 - val_accuracy: 0.6667
# Epoch 21/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6907 - accuracy: 0.6389 - val_loss: 0.6884 - val_accuracy: 0.6667
# Epoch 22/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6874 - accuracy: 0.6389 - val_loss: 0.6915 - val_accuracy: 0.6667
# Epoch 23/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6819 - accuracy: 0.6574 - val_loss: 0.7000 - val_accuracy: 0.6667
# Epoch 24/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6769 - accuracy: 0.6019 - val_loss: 0.7075 - val_accuracy: 0.5833
# Epoch 25/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6727 - accuracy: 0.6296 - val_loss: 0.7114 - val_accuracy: 0.4167
# Epoch 26/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6695 - accuracy: 0.6296 - val_loss: 0.7164 - val_accuracy: 0.4167
# Epoch 27/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6669 - accuracy: 0.6111 - val_loss: 0.7200 - val_accuracy: 0.4167
# Epoch 28/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6633 - accuracy: 0.6204 - val_loss: 0.7185 - val_accuracy: 0.5000
# Epoch 29/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6602 - accuracy: 0.6296 - val_loss: 0.7134 - val_accuracy: 0.5833
# Epoch 30/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6585 - accuracy: 0.5833 - val_loss: 0.7075 - val_accuracy: 0.6667
# Epoch 31/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6570 - accuracy: 0.6667 - val_loss: 0.7024 - val_accuracy: 0.6667
# Epoch 32/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6578 - accuracy: 0.6574 - val_loss: 0.7059 - val_accuracy: 0.6667
# Epoch 33/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6561 - accuracy: 0.6667 - val_loss: 0.7202 - val_accuracy: 0.6667
# Epoch 34/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6507 - accuracy: 0.6667 - val_loss: 0.7360 - val_accuracy: 0.5000
# Epoch 35/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6465 - accuracy: 0.6481 - val_loss: 0.7409 - val_accuracy: 0.5833
# Epoch 36/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6450 - accuracy: 0.6296 - val_loss: 0.7556 - val_accuracy: 0.5000
# Epoch 37/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6404 - accuracy: 0.6667 - val_loss: 0.7705 - val_accuracy: 0.4167
# Epoch 38/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6413 - accuracy: 0.6481 - val_loss: 0.7911 - val_accuracy: 0.3333
# Epoch 39/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6398 - accuracy: 0.6389 - val_loss: 0.7860 - val_accuracy: 0.4167
# Epoch 40/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6357 - accuracy: 0.6481 - val_loss: 0.7661 - val_accuracy: 0.5000
# Epoch 41/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6346 - accuracy: 0.6296 - val_loss: 0.7601 - val_accuracy: 0.5000
# Epoch 42/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6310 - accuracy: 0.6389 - val_loss: 0.7747 - val_accuracy: 0.5000
# Epoch 43/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6294 - accuracy: 0.6574 - val_loss: 0.7966 - val_accuracy: 0.4167
# Epoch 44/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6333 - accuracy: 0.6481 - val_loss: 0.8111 - val_accuracy: 0.4167
# Epoch 45/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6300 - accuracy: 0.6574 - val_loss: 0.7980 - val_accuracy: 0.4167
# Epoch 46/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6248 - accuracy: 0.6574 - val_loss: 0.7866 - val_accuracy: 0.5000
# Epoch 47/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6236 - accuracy: 0.6481 - val_loss: 0.7801 - val_accuracy: 0.5833
# Epoch 48/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6215 - accuracy: 0.6574 - val_loss: 0.7841 - val_accuracy: 0.5833
# Epoch 49/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6196 - accuracy: 0.6667 - val_loss: 0.7927 - val_accuracy: 0.5000
# Epoch 50/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6166 - accuracy: 0.6389 - val_loss: 0.8180 - val_accuracy: 0.5000

# %%
sh=x_test
score = model_m.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 8.59724235534668
# Test accuracy: 0.4000000059604645

# %%
import sklearn.metrics as metrics

y_test_pred = model_m.predict(x_test)
y_test_pred_labels = np.argmax(y_test_pred, axis=1)  # only necessary if output has one-hot-encoding, shape=(n_samples)
# print(y_test_pred_labels)
y_test_labels = np.argmax(y_test, axis=1)
# print(y_test_labels)
confusion_matrix = metrics.confusion_matrix(y_true=y_test_labels, y_pred=y_test_pred_labels)
# Out:
# 1/1 [==============================] - 0s 86ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sn
df_cm = pd.DataFrame(confusion_matrix, index=range(2), columns=range(2))
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='g') # font size

plt.xlabel("Target Class")
plt.ylabel("Output Class")

plt.show()

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.layers as keras

# tf.enable_eager_execution()


def parameter_count():
    total = 0
    #for v in tf.trainable_variables():
    for v in tf.Variable():
        v_elements = 1
        for dim in v.get_shape():
            v_elements *= dim.value

        total += v_elements
    return total

# %%
def combined_dataset(features, labels):
    assert features.shape[0] == labels.shape[0]
    dataset = tf.data.Dataset.from_tensor_slices(({'time_series': features}, labels))
    return dataset

def class_for_element(features, labels):
    return labels

# For training
def train_input_fn():
    print("I am here")
    dataset = combined_dataset(x_train, y_train)
    print( x_train.shape )
    return dataset.repeat().shuffle(5000).batch(50).prefetch(1)

# For evaluation and metrics
def eval_input_fn():
    dataset = combined_dataset(x_test, y_test)
    return dataset.batch(1000).prefetch(1)

# %%
def conv_unit(unit, input_layer):
    s = '_' + str(unit)
    layer = keras.Conv1D(name='Conv1' + s, filters=32, kernel_size=5, strides=1, padding='same', activation='relu')(input_layer)
    layer = keras.Conv1D(name='Conv2' + s, filters=32, kernel_size=5, strides=1, padding='same', activation=None)(layer )
    layer = keras.Add(name='ResidualSum' + s)([layer, input_layer])
    layer = keras.Activation("relu", name='Act' + s)(layer)
    layer = keras.MaxPooling1D(name='MaxPool' + s, pool_size=5, strides=2)(layer)
    return layer

def cnn_model(input_layer, mode, params):
    current_layer = keras.Conv1D(filters=32, kernel_size=5, strides=1)(input_layer)

    for i in range(5):
        current_layer = conv_unit(i + 1, current_layer)

    current_layer = keras.Flatten()(current_layer)
    current_layer = keras.Dense(32, name='FC1', activation='relu')(current_layer)
    logits = keras.Dense(5, name='Output')(current_layer)

    print('Parameter count:', parameter_count())
    return logits

# %%
CNN_MODEL_DIR = './Models/CNN-P1'

# %%
# Initial learning rate
INITIAL_LEARNING_RATE = 0.001

# Learning rate decay per LR_DECAY_STEPS steps (1.0 = no decay)
LR_DECAY_RATE = 0.5

# Number of steps for LR to decay by LR_DECAY_RATE
LR_DECAY_STEPS = 4000

# Threshold for gradient clipping
GRADIENT_NORM_THRESH = 10.0

# Select model to train
MODEL_DIR = CNN_MODEL_DIR
MODEL_FN = cnn_model

def classifier_fn(features, labels, mode, params):
    is_training = mode == tf.estimator.ModeKeys.TRAIN
    #input_layer=tf.keras.layers.DenseFeatures(feature_columns=features)
    input_layer = tf.compat.v1.feature_column.input_layer(features, params['feature_columns'])
    input_layer = tf.expand_dims(input_layer, -1)

    logits = MODEL_FN(input_layer, mode, params)

    # For prediction, exit here
    predicted_classes = tf.argmax(logits, 1)
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {
            'class_ids': predicted_classes[:, tf.newaxis],
            'probabilities': tf.nn.softmax(logits),
            'logits': logits,
        }
        return tf.estimator.EstimatorSpec(mode, predictions=predictions)

    # For training and evaluation, compute the loss (MSE)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

    accuracy = tf.metrics.accuracy(labels=labels, predictions=predicted_classes, name='acc_op')
    metrics = {'accuracy': accuracy}
    tf.summary.scalar('accuracy', accuracy[1])

    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(mode, loss=loss, eval_metric_ops=metrics)

    # For training...
    global_step = tf.train.get_global_step()
    learning_rate = tf.train.exponential_decay(INITIAL_LEARNING_RATE, global_step, LR_DECAY_STEPS, LR_DECAY_RATE)

    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    #optimizer = tf.contrib.estimator.clip_gradients_by_norm(optimizer, GRADIENT_NORM_THRESH)

    train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

# %%
def parameter_count():
    total = 0
    for v in tf.trainable_variables():
        v_elements = 1
        for dim in v.get_shape():
            v_elements *= dim.value
        total += v_elements
    return total

# %%
feature_columns = [tf.feature_column.numeric_column('time_series', [187])]

estimator = tf.compat.v1.estimator.Estimator(
    model_fn=classifier_fn,
    model_dir=MODEL_DIR,
    params={
        'feature_columns': feature_columns,
    })

estimator.train(train_input_fn, steps=4000)
info = estimator.evaluate(input_fn=eval_input_fn)
# Out:
# WARNING:tensorflow:From <ipython-input-128-bbd015fa12fc>:1: numeric_column (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
# WARNING:tensorflow:From <ipython-input-128-bbd015fa12fc>:3: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/estimator.py:1844: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/estimator.py:385: StopAtStepHook.__init__ (from tensorflow.python.training.basic_session_run_hooks) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From <ipython-input-127-6a50a43dea33>:20: input_layer (from tensorflow.python.feature_column.feature_column) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/feature_column/feature_column.py:216: NumericColumn._get_dense_tensor (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/feature_column/feature_column.py:2207: NumericColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/feature_column/feature_column.py:220: NumericColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# I am here
# (120, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-bbd015fa12fc> in <cell line: 10>()
#       8     })
#       9
# ---> 10 estimator.train(train_input_fn, steps=4000)
#      11 info = estimator.evaluate(input_fn=eval_input_fn)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     358
#     359       saving_listeners = _check_listeners_type(saving_listeners)
# --> 360       loss = self._train_model(input_fn, hooks, saving_listeners)
#     361       tf.compat.v1.logging.info('Loss for final step: %s.', loss)
#     362       return self
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1186       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1187     else:
# -> 1188       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1189
#    1190   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1214           self._get_features_and_labels_from_input_fn(input_fn, ModeKeys.TRAIN))
#    1215       worker_hooks.extend(input_hooks)
# -> 1216       estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#    1217                                            self.config)
#    1218       global_step_tensor = tf.compat.v1.train.get_global_step(g)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1174
#    1175     tf.compat.v1.logging.info('Calling model_fn.')
# -> 1176     model_fn_results = self._model_fn(features=features, **kwargs)
#    1177     tf.compat.v1.logging.info('Done calling model_fn.')
#    1178
#
# <ipython-input-127-6a50a43dea33> in classifier_fn(features, labels, mode, params)
#      21     input_layer = tf.expand_dims(input_layer, -1)
#      22
# ---> 23     logits = MODEL_FN(input_layer, mode, params)
#      24
#      25     # For prediction, exit here
#
# <ipython-input-125-a24c3e60f624> in cnn_model(input_layer, mode, params)
#      18     logits = keras.Dense(5, name='Output')(current_layer)
#      19
# ---> 20     print('Parameter count:', parameter_count())
#      21     return logits
#
# <ipython-input-121-76b5b5965783> in parameter_count()
#       9     total = 0
#      10     #for v in tf.trainable_variables():
# ---> 11     for v in tf.Variable():
#      12         v_elements = 1
#      13         for dim in v.get_shape():
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    1953       experimental_enable_variable_lifting = True
#    1954     if initial_value is None:
# -> 1955       raise ValueError("The `initial_value` arg to `tf.Variable` must "
#    1956                        "be specified except when you are not providing a "
#    1957                        "`variable_def`. You provided neither.")
#
# ValueError: The `initial_value` arg to `tf.Variable` must be specified except when you are not providing a `variable_def`. You provided neither.
