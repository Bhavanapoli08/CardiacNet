# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
# %pylab inline
# %config InlineBackend.figure_formats = ['retina']
from imutils import paths
import time   # time1 = time.time(); print('Time taken: {:.1f} sec'.format(time.time() - time1))
import cv2
import pickle
import warnings
warnings.filterwarnings("ignore")
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import keras
import keras.utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam

from tensorflow.keras import utils as np_utils

from tensorflow.keras.utils import to_categorical
from keras.preprocessing import image
from sklearn.model_selection import train_test_split

from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Convolution1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense

# %%
from google.colab import drive
drive.mount._DEBUG = True
drive.mount('/content/MyDrive', force_remount=True)
# Out:
# unset HISTFILE; export PS1="root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: "
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# /content# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: umount -f /content/MyDrive || umount /content/MyDrive; pkill -9 -x drive
# umount: /content/MyDrive: no mount point specified.
# umount: /content/MyDrive: no mount point specified.
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: pkill -9 -f /opt/google/drive/directoryprefetcher_binary
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: ( while `sleep 0.5`; do if [[ -d "/content/MyDrive" && "$(ls -A /content/MyDrive)" != "" ]]; then echo "google.colab.drive MOUNTED"; break; fi; done ) &
# [1] 838
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: ( /opt/google/drive/drive --features=fuse_max_background:1000,max_read_qps:1000,max_write_qps:1000,max_operation_batch_size:15,max_parallel_push_task_instances:10,opendir_timeout_ms:120000,virtual_folders_omit_spaces:true,read_only_mode:false --inet_family=IPV4_ONLY --metadata_server_auth_uri=172.28.0.1:8009/computeMetadata/v1 --preferences=trusted_root_certs_file_path:/opt/google/drive/roots.pem,mount_point_path:/content/MyDrive 2>&1 | grep --line-buffered -E "Drive File Stream encountered a problem and has stopped|The domain policy has disabled Drive File Stream"; echo "drive EXITED"; ) &
# [2] 840
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: google.colab.drive MOUNTED
# fuser -kw "/root/.config/Google/DriveFS/Logs/timeouts.txt" ; rm -rf "/root/.config/Google/DriveFS/Logs/timeouts.txt"
# Specified filename /root/.config/Google/DriveFS/Logs/timeouts.txt does not exist.
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: nohup bash -c 'tail -n +0 -F "/root/.config/Google/DriveFS/Logs/drive_fs.txt" | python3 /opt/google/drive/drive-filter.py > "/root/.config/Google/DriveFS/Logs/timeouts.txt" ' < /dev/null > /dev/null 2>&1 &
# [3] 1049
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: nohup bash -c '/opt/google/drive/directoryprefetcher_binary -mountpoint=/content/MyDrive' >> /root/.config/Google/DriveFS/Logs/dpb.txt 2>&1 &
# [4] 1052
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: disown -a
# root@731652e3d1ec-d645ed54faf44205821c4bf23c3d0780: exit
# Mounted at /content/MyDrive

# %%
# Enter the directory
# !cd /content/MyDrive/MyDrive/ECG

# %%
#Files 1
with open('/content/MyDrive/MyDrive/ECG/dataset_dict.pickle', 'rb') as file:
    dataset_dict = pickle.load(file)
# Sets with truncated max and min to remove strays
with open('/content/MyDrive/MyDrive/ECG/dataset_dict_nominmax.pickle', 'rb') as file:
    dataset_dict = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e9ccc0037733> in <cell line: 2>()
#       1 #Files 1
# ----> 2 with open('/content/MyDrive/MyDrive/ECG/dataset_dict.pickle', 'rb') as file:
#       3     dataset_dict = pickle.load(file)
#       4 # Sets with truncated max and min to remove strays
#       5 with open('/content/MyDrive/MyDrive/ECG/dataset_dict_nominmax.pickle', 'rb') as file:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/MyDrive/MyDrive/ECG/dataset_dict.pickle'

# %%
import pickle

pickle_file_path = '/content/MyDrive/MyDrive/ECG/dataset_dict.pickle'

try:
    with open(pickle_file_path, 'rb') as file:
        dataset_dict = pickle.load(file)
    # Continue processing data
except FileNotFoundError:
    print(f"File {pickle_file_path} not found.")
# Out:
# File /content/MyDrive/MyDrive/ECG/dataset_dict.pickle not found.
